# %%
# Import necessary libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Load the breast cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the classifier
clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.97

# %%
def calculate_performance_metrics(y_true, y_pred):
    """
    Calculate performance metrics based on true labels and predicted labels.

    Parameters:
    - y_true: list or array of true labels
    - y_pred: list or array of predicted labels

    Returns:
    - A dictionary containing accuracy, precision, recall, F1-score, FPR, and FNR
    """
    # Initialize counters for true positives, false positives, true negatives, and false negatives
    true_positives = 0
    false_positives = 0
    true_negatives = 0
    false_negatives = 0

    # Calculate TP, FP, TN, FN
    for true, pred in zip(y_true, y_pred):
        if true == 1 and pred == 1:
            true_positives += 1
        elif true == 0 and pred == 1:
            false_positives += 1
        elif true == 0 and pred == 0:
            true_negatives += 1
        elif true == 1 and pred == 0:
            false_negatives += 1

    # Calculate metrics
    accuracy = (true_positives + true_negatives) / (true_positives + false_positives + true_negatives + false_negatives)
    precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) != 0 else 0
    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) != 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) != 0 else 0
    fpr = false_positives / (false_positives + true_negatives) if (false_positives + true_negatives) != 0 else 0
    fnr = false_negatives / (true_positives + false_negatives) if (true_positives + false_negatives) != 0 else 0

    return {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1_score,
        "FPR": fpr,
        "FNR": fnr
    }

# Example usage:
y_true = [1, 0, 1, 1, 0, 1, 0, 0]
y_pred = [1, 1, 1, 0, 0, 1, 0, 0]

metrics = calculate_performance_metrics(y_true, y_pred)
print(f'Accuracy: {metrics["accuracy"]:.2f}')
print(f'Precision: {metrics["precision"]:.2f}')
print(f'Recall: {metrics["recall"]:.2f}')
print(f'F1 Score: {metrics["f1_score"]:.2f}')
print(f'False Positive Rate (FPR): {metrics["FPR"]:.2f}')
print(f'False Negative Rate (FNR): {metrics["FNR"]:.2f}')
# Out:
# Accuracy: 0.75
# Precision: 0.75
# Recall: 0.75
# F1 Score: 0.75
# False Positive Rate (FPR): 0.25
# False Negative Rate (FNR): 0.25

# %%
from sklearn.model_selection import KFold
from sklearn.datasets import load_breast_cancer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
import numpy as np

# Load the dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Initialize 10-fold cross-validation
kf = KFold(n_splits=10, shuffle=True, random_state=42)

# Initialize the classifier
clf = DecisionTreeClassifier(random_state=42)

# To store metrics for each fold
metrics = []

def calculate_tss(tp, tn, fp, fn):
    sensitivity = tp / (tp + fn) if (tp + fn) != 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) != 0 else 0
    return sensitivity - (1 - specificity)

def calculate_hss(tp, tn, fp, fn):
    denominator = ((tp + fn) * (fn + tn) + (tp + fp) * (fp + tn))
    return 2 * ((tp * tn - fn * fp) / denominator) if denominator != 0 else 0

# Perform 10-fold cross-validation
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    # Train the classifier
    clf.fit(X_train, y_train)
    
    # Predict on the test set
    y_pred = clf.predict(X_test)
    
    # Calculate confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    
    # Calculate TSS and HSS
    tss = calculate_tss(tp, tn, fp, fn)
    hss = calculate_hss(tp, tn, fp, fn)
    
    # Store metrics
    metrics.append((tp, tn, fp, fn, tss, hss))

# Convert metrics list to a NumPy array for easy averaging
metrics_np = np.array(metrics)

# Calculate average metrics across all folds
avg_metrics = np.mean(metrics_np, axis=0)

print("Average metrics across all 10 folds:")
print(f"TP: {avg_metrics[0]:.0f}, TN: {avg_metrics[1]:.0f}, FP: {avg_metrics[2]:.0f}, FN: {avg_metrics[3]:.0f}, TSS: {avg_metrics[4]:.2f}, HSS: {avg_metrics[5]:.2f}")
# Out:
# Average metrics across all 10 folds:
# TP: 34, TN: 19, FP: 2, FN: 2, TSS: 0.86, HSS: 0.86

# %% [markdown]
# LSTM

# %%
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.utils import to_categorical

# Load the dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Because LSTMs expect 3D input (samples, timesteps, features), 
# and our data is not naturally sequential, we'll treat each feature as a timestep.
# This is just for demonstration and not a recommended approach for this dataset.

# Normalize the data to be between 0 and 1
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Reshape X to be 3D
X_reshaped = np.reshape(X_scaled, (X_scaled.shape[0], X_scaled.shape[1], 1))

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y, test_size=0.3, random_state=42)

# Convert labels to categorical (one-hot encoding)
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# Build the LSTM model
model = Sequential()
model.add(LSTM(32, input_shape=(X_train.shape[1], 1), activation='relu', return_sequences=True))
model.add(LSTM(16, activation='relu'))
model.add(Dense(2, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train_categorical, epochs=100, batch_size=64, validation_split=0.2, verbose=2)

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test_categorical)
print(f'Test Accuracy: {accuracy:.2f}')
# Out:
# Epoch 1/100
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 5/5 - 1s - 249ms/step - accuracy: 0.6541 - loss: 0.6900 - val_accuracy: 0.6625 - val_loss: 0.6869
# Epoch 2/100
# 5/5 - 0s - 12ms/step - accuracy: 0.6321 - loss: 0.6847 - val_accuracy: 0.6500 - val_loss: 0.6824
# Epoch 3/100
# 5/5 - 0s - 11ms/step - accuracy: 0.6415 - loss: 0.6788 - val_accuracy: 0.6875 - val_loss: 0.6761
# Epoch 4/100
# 5/5 - 0s - 11ms/step - accuracy: 0.6667 - loss: 0.6720 - val_accuracy: 0.7250 - val_loss: 0.6678
# Epoch 5/100
# 5/5 - 0s - 12ms/step - accuracy: 0.7327 - loss: 0.6618 - val_accuracy: 0.7625 - val_loss: 0.6556
# Epoch 6/100
# 5/5 - 0s - 11ms/step - accuracy: 0.7736 - loss: 0.6462 - val_accuracy: 0.8250 - val_loss: 0.6348
# Epoch 7/100
# 5/5 - 0s - 11ms/step - accuracy: 0.8616 - loss: 0.6171 - val_accuracy: 0.8250 - val_loss: 0.5940
# Epoch 8/100
# 5/5 - 0s - 11ms/step - accuracy: 0.8868 - loss: 0.5557 - val_accuracy: 0.9000 - val_loss: 0.5011
# Epoch 9/100
# 5/5 - 0s - 11ms/step - accuracy: 0.8899 - loss: 0.4515 - val_accuracy: 0.8375 - val_loss: 0.3916
# Epoch 10/100
# 5/5 - 0s - 10ms/step - accuracy: 0.8899 - loss: 0.4264 - val_accuracy: 0.8250 - val_loss: 0.4360
# Epoch 11/100
# 5/5 - 0s - 11ms/step - accuracy: 0.8805 - loss: 0.3432 - val_accuracy: 0.9125 - val_loss: 0.3066
# Epoch 12/100
# 5/5 - 0s - 10ms/step - accuracy: 0.8994 - loss: 0.3311 - val_accuracy: 0.8375 - val_loss: 0.3258
# Epoch 13/100
100
# 5/5 - 0s - 12ms/step - accuracy: 0.9308 - loss: 0.1698 - val_accuracy: 0.9125 - val_loss: 0.1602
# Epoch 93/100
# 5/5 - 0s - 12ms/step - accuracy: 0.9182 - loss: 0.1791 - val_accuracy: 0.9125 - val_loss: 0.1567
# Epoch 94/100
# 5/5 - 0s - 12ms/step - accuracy: 0.9277 - loss: 0.1721 - val_accuracy: 0.9375 - val_loss: 0.1552
# Epoch 95/100
# 5/5 - 0s - 12ms/step - accuracy: 0.9245 - loss: 0.1733 - val_accuracy: 0.9000 - val_loss: 0.1540
# Epoch 96/100
# 5/5 - 0s - 12ms/step - accuracy: 0.9151 - loss: 0.1735 - val_accuracy: 0.9375 - val_loss: 0.1525
# Epoch 97/100
# 5/5 - 0s - 12ms/step - accuracy: 0.9214 - loss: 0.1652 - val_accuracy: 0.9125 - val_loss: 0.1518
# Epoch 98/100
# 5/5 - 0s - 12ms/step - accuracy: 0.9214 - loss: 0.1654 - val_accuracy: 0.9250 - val_loss: 0.1517
# Epoch 99/100
# 5/5 - 0s - 12ms/step - accuracy: 0.9182 - loss: 0.1627 - val_accuracy: 0.9000 - val_loss: 0.1552
# Epoch 100/100
# 5/5 - 0s - 12ms/step - accuracy: 0.9182 - loss: 0.1625 - val_accuracy: 0.9375 - val_loss: 0.1470
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9566 - loss: 0.1106
# Test Accuracy: 0.95

# %% [markdown]
# Support Vector Machines

# %%
# Import necessary libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score

# Load the breast cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create an SVM classifier. Here we use a pipeline to first standardize the dataset.
clf = make_pipeline(StandardScaler(), SVC(kernel='linear', C=1.0))

# Train the classifier
clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.98

# %% [markdown]
# Decision Trees

# %%
# Import necessary libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load the breast cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=42)

# Train the classifier
clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.94

# %% [markdown]
# KNN, K-Nearest Neighbor

# %%
# Import necessary libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score

# Load the breast cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create a KNN classifier. Here we use a pipeline to first standardize the dataset.
# Standardization is important for KNN because it is distance-based.
knn_clf = make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors=5))

# Train the classifier
knn_clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = knn_clf.predict(X_test)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.96

# %% [markdown]
# Algorithm (Conv1D)

# %%
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# Load the dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Normalize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Reshape X to have the shape (samples, timesteps, features) for Conv1D
X_reshaped = np.reshape(X_scaled, (X_scaled.shape[0], X_scaled.shape[1], 1))

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y, test_size=0.3, random_state=42)

# Convert labels to one-hot encoding
y_train_ohe = to_categorical(y_train)
y_test_ohe = to_categorical(y_test)

# Define the Conv1D model
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dense(2, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train_ohe, epochs=100, batch_size=32, validation_split=0.2, verbose=2)

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test_ohe)
print(f'Test Accuracy: {accuracy:.2f}')
# Out:
# Epoch 1/100
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# 10/10 - 1s - 54ms/step - accuracy: 0.8805 - loss: 0.4465 - val_accuracy: 0.9500 - val_loss: 0.2747
# Epoch 2/100
# 10/10 - 0s - 3ms/step - accuracy: 0.9434 - loss: 0.2107 - val_accuracy: 0.9500 - val_loss: 0.1564
# Epoch 3/100
# 10/10 - 0s - 4ms/step - accuracy: 0.9591 - loss: 0.1335 - val_accuracy: 0.9500 - val_loss: 0.1104
# Epoch 4/100
# 10/10 - 0s - 4ms/step - accuracy: 0.9686 - loss: 0.1030 - val_accuracy: 0.9500 - val_loss: 0.0952
# Epoch 5/100
# 10/10 - 0s - 4ms/step - accuracy: 0.9780 - loss: 0.0864 - val_accuracy: 0.9500 - val_loss: 0.0862
# Epoch 6/100
# 10/10 - 0s - 3ms/step - accuracy: 0.9811 - loss: 0.0763 - val_accuracy: 0.9375 - val_loss: 0.0870
# Epoch 7/100
# 10/10 - 0s - 3ms/step - accuracy: 0.9811 - loss: 0.0724 - val_accuracy: 0.9375 - val_loss: 0.0826
# Epoch 8/100
# 10/10 - 0s - 3ms/step - accuracy: 0.9811 - loss: 0.0671 - val_accuracy: 0.9375 - val_loss: 0.0790
# Epoch 9/100
# 10/10 - 0s - 3ms/step - accuracy: 0.9811 - loss: 0.0624 - val_accuracy: 0.9375 - val_loss: 0.0796
# Epoch 10/100
# 10/10 - 0s - 3ms/step - accuracy: 0.9811 - loss: 0.0600 - val_accuracy: 0.9375 - val_loss: 0.0799
# Epoch 11/100
# 10/10 - 0s - 3ms/step - accuracy: 0.9811 - loss: 0.0582 - val_accuracy: 0.9375 - val_loss: 0.0880
# Epoch 12/100
# 10/10 - 0s - 3ms/step - accuracy: 0.9811 - loss: 0.0591 - val_accuracy: 0.9625 - val_loss: 0.0808
# Epoch 13/100
# 10/10 - 0s - 4ms/step - accuracy: 0.9874 - loss: 0.0527 - val_accuracy: 0.9375 - val_loss: 0.0863
# Epoch 14/100
# 10/10 - 0s - 4ms/step - accuracy: 0.9874 - loss: 0.0511 - val_accuracy: 0.9375 - val_loss: 0.0838
# Epoch 15/100
# 10/10 - 0s - 3ms/step - accuracy: 0.9874 - loss: 0.0486 - val_accuracy: 0.9375 - val_loss: 0.0828
# Epoch 16/100
# 10/10 - 0s - 3ms/step - accuracy: 0.9874 - loss: 0.0485 - val_accuracy: 0.9375 - val_loss: 0.0873
# Epoch 17/100
# 10/10 - 0s - 3ms/step - accuracy: 0.9874 - loss: 0.0449 - val_accuracy: 0.9500 - val_loss: 0.0833
# Epoch 18/100
# 10/10 - 0s - 3ms/step - accuracy: 0.9874 - loss: 0.0436 - val_accuracy: 0.9375 - val_loss: 0.0849
# Epoch 19/100
# 10/10 - 0s - 3ms/step - accuracy: 0.9874 - loss: 0.0407 - val_accuracy: 0.9375 - val_loss: 0.0874
# Epoch 20/100
# 10/10 - 0s - 3ms/step - accuracy: 0.9874 - loss: 0.0400 - val_accuracy: 0.9375 - val_loss: 0.0893
# Epoch 21/100
# 10/10 - 0s - 3ms/step - accuracy: 0.9874 - loss: 0.0396 - val_accuracy: 0.9375 - val_loss: 0.0906
# Epoch 22/100
# 10/10 - 0s - 3ms/step - accuracy: 0.9906 - loss: 0.0404 - val_accuracy: 0.9500 - val_loss: 0.0885
# Epoch 23/100
# 10/10 - 0s - 3ms/step - accuracy: 0.9906 - loss: 0.0353 - val_accuracy: 0.9375 - val_loss: 0.0893
# Epoch 24/100
- 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.9250 - val_loss: 0.1207
# Epoch 67/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9250 - val_loss: 0.1258
# Epoch 68/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.9250 - val_loss: 0.1249
# Epoch 69/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.9250 - val_loss: 0.1267
# Epoch 70/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9250 - val_loss: 0.1278
# Epoch 71/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9375 - val_loss: 0.1312
# Epoch 72/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.9250 - val_loss: 0.1299
# Epoch 73/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.9250 - val_loss: 0.1307
# Epoch 74/100
# 10/10 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9375 - val_loss: 0.1317
# Epoch 75/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9250 - val_loss: 0.1320
# Epoch 76/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9250 - val_loss: 0.1325
# Epoch 77/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9375 - val_loss: 0.1370
# Epoch 78/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9250 - val_loss: 0.1356
# Epoch 79/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9250 - val_loss: 0.1363
# Epoch 80/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9375 - val_loss: 0.1366
# Epoch 81/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9375 - val_loss: 0.1406
# Epoch 82/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9375 - val_loss: 0.1364
# Epoch 83/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9375 - val_loss: 0.1389
# Epoch 84/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9375 - val_loss: 0.1453
# Epoch 85/100
# 10/10 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9250 - val_loss: 0.1394
# Epoch 86/100
# 10/10 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9375 - val_loss: 0.1406
# Epoch 87/100
# 10/10 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9375 - val_loss: 0.1430
# Epoch 88/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9375 - val_loss: 0.1432
# Epoch 89/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9375 - val_loss: 0.1446
# Epoch 90/100
# 10/10 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9375 - val_loss: 0.1452
# Epoch 91/100
# 10/10 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9375 - val_loss: 0.1479
# Epoch 92/100
# 10/10 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9375 - val_loss: 0.1483
# Epoch 93/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9375 - val_loss: 0.1492
# Epoch 94/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9375 - val_loss: 0.1483
# Epoch 95/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9375 - val_loss: 0.1518
# Epoch 96/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9375 - val_loss: 0.1504
# Epoch 97/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9375 - val_loss: 0.1519
# Epoch 98/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9375 - val_loss: 0.1536
# Epoch 99/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9375 - val_loss: 0.1543
# Epoch 100/100
# 10/10 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9375 - val_loss: 0.1551
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - accuracy: 0.9710 - loss: 0.1492
# Test Accuracy: 0.97
